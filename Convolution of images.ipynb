# %%
#cnn: used to work on img and video processing
#nn : need data in only 1d format
#importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# from tensorflow.examples.tutorials.mnist import input_data
# %matplotlib inline
import pandas as pd
# Out:
# ----------------------------------------------------------
# ModuleNotFoundError      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6204/3231792268.py in <module>
#       2 import matplotlib.pyplot as plt
#       3 import tensorflow as tf
# ----> 4 from tensorflow.examples.tutorials.mnist import input_data
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#       6 import pandas as pd
#
# ModuleNotFoundError: No module named 'tensorflow.examples'

# %%
# dataset= pd.read_csv('./data/mnist') 
data = pd.read_csv("./data/mnist", one_hot = True)
# Out:
# ----------------------------------------------------------
# TypeError                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6204/1091754889.py in <module>
#       1 # dataset= pd.read_csv('./data/mnist')
# ----> 2 data = pd.read_csv("./data/mnist", one_hot = True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: read_csv() got an unexpected keyword argument 'one_hot'

# %%
from scipy import misc

# %%
img = misc.ascent()

# %%
img
# Out:
# array([[ 83,  83,  83, ..., 117, 117, 117],
#        [ 82,  82,  83, ..., 117, 117, 117],
#        [ 80,  81,  83, ..., 117, 117, 117],
#        ...,
#        [178, 178, 178, ...,  57,  59,  57],
#        [178, 178, 178, ...,  56,  57,  57],
#        [178, 178, 178, ...,  57,  57,  58]])

# %%
img.shape
# Out:
# (512, 512)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img, cmap="gray")

# %%
from scipy.signal import convolve2d

# %%
 cimg = convolve2d(img,f)

# %%
f = np.array([
[1,2,3],
[1,0,-1],
[1,1,1]
])

# %%
plt.imshow(cimg,cmap="gray")
