# %%
from PIL import Image

# %%
im = Image.open('my.jpg')

# %%
im.rotate(angle=90)
# Out:
# <PIL.Image.Image image mode=RGB size=500x150 at 0x27F6E5D91F0>

# %%
im.transpose(Image.ROTATE_180)
# Out:
# <PIL.Image.Image image mode=RGB size=500x150 at 0x27F6E82D0A0>

# %%
Image.load_img()
# Out:
# ----------------------------------------------------------
# AttributeError           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17712/488441549.py in <module>
# ----> 1 Image.load_img()
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in __getattr__(name)
#      75                 )
#      76                 return categories[name]
# ---> 77         raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#      78
#      79
#
# AttributeError: module 'PIL.Image' has no attribute 'load_img'

# %%
from keras.application import vgg16
# Out:
# ----------------------------------------------------------
# ModuleNotFoundError      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17712/153071535.py in <module>
# ----> 1 from keras.application import vgg16
#
# ModuleNotFoundError: No module named 'keras.application'

# %%
model = vgg16.VGG16(weightd='imageNet')

# %%
from keras.preprocessing import Image

# %%
img.size()
# Out:
# ----------------------------------------------------------
# NameError                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17712/931182031.py in <module>
# ----> 1 img.size()
#
# NameError: name 'img' is not defined

# %%
import numpy as np
a = np.array([1,2])

# %%
a
# Out:
# array([1, 2])

# %%
a.shape
# Out:
# (2,)
